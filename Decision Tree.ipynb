# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# 1. Charger le dataset Iris
iris = load_iris()
X = iris.data  # Caractéristiques (longueur/largeur des pétales/sépales)
y = iris.target  # Classes (Setosa, Versicolour, Virginica)
feature_names = iris.feature_names
class_names = iris.target_names

# 2. Diviser les données en ensemble d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Créer et entraîner le modèle de l'arbre de décision
model = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
model.fit(X_train, y_train)

# 4. Faire des prédictions
y_pred = model.predict(X_test)

# 5. Évaluer le modèle
accuracy = accuracy_score(y_test, y_pred)
print(f"Exactitude du modèle : {accuracy:.2f}")

# 6. Visualiser l'arbre de décision
plt.figure(figsize=(12, 8))
plot_tree(
    model,
    feature_names=feature_names,
    class_names=class_names,
    filled=True,
    rounded=True,
    fontsize=10
)
plt.title("Arbre de Décision pour le dataset Iris")
plt.show()
# Out:
# Exactitude du modèle : 1.00
